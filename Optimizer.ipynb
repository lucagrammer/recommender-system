# %%
import numpy as np
import pandas as pd
import scipy.sparse as sp
import FileManager

# %%
ratings = FileManager.load_data()
users_to_recommend = np.array(FileManager.load_target()).squeeze()
urm_all,urm_train,urm_validation= FileManager.split_data(ratings)
urm_train_validation = urm_train + urm_validation
# Out:
# > Importing file...
# > Importing file... Completed!
# > Importing file...
# > Importing file... Completed!

# %%
from Evaluation.Evaluator import EvaluatorHoldout

evaluator_validation = EvaluatorHoldout(urm_validation, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 13644 ( 0.0%) Users that have less than 1 test interactions

# %%
from skopt.space import Real, Integer, Categorical

hyperparameters_range_dictionary = {
    "topK": Integer(200,250),
    "shrink": Integer(1,5),
    "similarity": Categorical(["cosine"]),
    "normalize": Categorical([True]),
}

# %%
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

recommender_class = ItemKNNCFRecommender

hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_validation)

from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
  
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [urm_train],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [urm_train_validation],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {}
)

# %%
import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 10  # NUMBER OF CASES
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
# RUN THE OPTIMIZER

hyperparameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 241, 'shrink': 1, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 1037.85 column/sec. Elapsed time 17.40 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 29.43 sec. Users per second: 464
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 241, 'shrink': 1, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3463574, PRECISION_RECALL_MIN_DEN: 0.3476477, RECALL: 0.0590467, MAP: 0.2094378, MAP_MIN_DEN: 0.2100382, MRR: 0.6098080, NDCG: 0.3644994, F1: 0.1008932, HIT_RATE: 0.9500147, ARHR_ALL_HITS: 1.1117055, NOVELTY: 0.0053048, AVERAGE_POPULARITY: 0.6654809, DIVERSITY_MEAN_INTER_LIST: 0.7990288, DIVERSITY_HERFINDAHL: 0.9798970, COVERAGE_ITEM: 0.0532698, COVERAGE_ITEM_CORRECT: 0.0285730, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9495971, DIVERSITY_GINI: 0.0037915, SHANNON_ENTROPY: 6.3108431, RATIO_DIVERSITY_HERFINDAHL: 0.9802752, RATIO_DIVERSITY_GINI: 0.0152865, RATIO_SHANNON_ENTROPY: 0.5093256, RATIO_AVERAGE_POPULARITY: 3.2761053, RATIO_NOVELTY: 0.0249608,
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 47.9713
# Function value obtained: -0.2094
# Current minimum: -0.2094
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 236, 'shrink': 4, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 885.17 column/sec. Elapsed time 20.40 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 28.13 sec. Users per second: 485
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 236, 'shrink': 4, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3464893, PRECISION_RECALL_MIN_DEN: 0.3478038, RECALL: 0.0590645, MAP: 0.2096293, MAP_MIN_DEN: 0.2102454, MRR: 0.6110433, NDCG: 0.3649196, F1: 0.1009249, HIT_RATE: 0.9497215, ARHR_ALL_HITS: 1.1137669, NOVELTY: 0.0053041, AVERAGE_POPULARITY: 0.6653253, DIVERSITY_MEAN_INTER_LIST: 0.7997081, DIVERSITY_HERFINDAHL: 0.9799649, COVERAGE_ITEM: 0.0533252, COVERAGE_ITEM_CORRECT: 0.0286284, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9493040, DIVERSITY_GINI: 0.0038007, SHANNON_ENTROPY: 6.3153610, RATIO_DIVERSITY_HERFINDAHL: 0.9803431, RATIO_DIVERSITY_GINI: 0.0153237, RATIO_SHANNON_ENTROPY: 0.5096903, RATIO_AVERAGE_POPULARITY: 3.2753389, RATIO_NOVELTY: 0.0249577,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 49.9098
# Function value obtained: -0.2096
# Current minimum: -0.2096
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'topK': 205, 'shrink': 3, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 967.38 column/sec. Elapsed time 18.67 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 27.53 sec. Users per second: 496
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 205, 'shrink': 3, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3472222, PRECISION_RECALL_MIN_DEN: 0.3485355, RECALL: 0.0592287, MAP: 0.2106693, MAP_MIN_DEN: 0.2113336, MRR: 0.6166914, NDCG: 0.3663595, F1: 0.1011956, HIT_RATE: 0.9508942, ARHR_ALL_HITS: 1.1201613, NOVELTY: 0.0053112, AVERAGE_POPULARITY: 0.6604589, DIVERSITY_MEAN_INTER_LIST: 0.8097878, DIVERSITY_HERFINDAHL: 0.9809728, COVERAGE_ITEM: 0.0550418, COVERAGE_ITEM_CORRECT: 0.0289053, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9504762, DIVERSITY_GINI: 0.0039818, SHANNON_ENTROPY: 6.3869840, RATIO_DIVERSITY_HERFINDAHL: 0.9813514, RATIO_DIVERSITY_GINI: 0.0160539, RATIO_SHANNON_ENTROPY: 0.5154707, RATIO_AVERAGE_POPULARITY: 3.2513824, RATIO_NOVELTY: 0.0249912,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 48.4278
# Function value obtained: -0.2107
# Current minimum: -0.2107
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 245, 'shrink': 1, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 1010.02 column/sec. Elapsed time 17.88 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 29.07 sec. Users per second: 469
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 245, 'shrink': 1, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3468264, PRECISION_RECALL_MIN_DEN: 0.3481037, RECALL: 0.0590642, MAP: 0.2096197, MAP_MIN_DEN: 0.2102083, MRR: 0.6117070, NDCG: 0.3649391, F1: 0.1009386, HIT_RATE: 0.9503078, ARHR_ALL_HITS: 1.1133144, NOVELTY: 0.0053044, AVERAGE_POPULARITY: 0.6657807, DIVERSITY_MEAN_INTER_LIST: 0.7983982, DIVERSITY_HERFINDAHL: 0.9798340, COVERAGE_ITEM: 0.0535467, COVERAGE_ITEM_CORRECT: 0.0284069, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9498901, DIVERSITY_GINI: 0.0037863, SHANNON_ENTROPY: 6.3076835, RATIO_DIVERSITY_HERFINDAHL: 0.9802121, RATIO_DIVERSITY_GINI: 0.0152654, RATIO_SHANNON_ENTROPY: 0.5090706, RATIO_AVERAGE_POPULARITY: 3.2775811, RATIO_NOVELTY: 0.0249590,
#
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 48.8164
# Function value obtained: -0.2096
# Current minimum: -0.2107
# Iteration No: 5 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 217, 'shrink': 3, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 869.44 column/sec. Elapsed time 20.77 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 29.16 sec. Users per second: 468
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 217, 'shrink': 3, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3467825, PRECISION_RECALL_MIN_DEN: 0.3481243, RECALL: 0.0592712, MAP: 0.2105788, MAP_MIN_DEN: 0.2112435, MRR: 0.6163722, NDCG: 0.3661663, F1: 0.1012389, HIT_RATE: 0.9514805, ARHR_ALL_HITS: 1.1201591, NOVELTY: 0.0053082, AVERAGE_POPULARITY: 0.6626867, DIVERSITY_MEAN_INTER_LIST: 0.8054315, DIVERSITY_HERFINDAHL: 0.9805372, COVERAGE_ITEM: 0.0545988, COVERAGE_ITEM_CORRECT: 0.0286838, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9510623, DIVERSITY_GINI: 0.0039076, SHANNON_ENTROPY: 6.3551628, RATIO_DIVERSITY_HERFINDAHL: 0.9809157, RATIO_DIVERSITY_GINI: 0.0157546, RATIO_SHANNON_ENTROPY: 0.5129025, RATIO_AVERAGE_POPULARITY: 3.2623496, RATIO_NOVELTY: 0.0249769,
#
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 52.2101
# Function value obtained: -0.2106
# Current minimum: -0.2107
# Iteration No: 6 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 203, 'shrink': 5, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 971.80 column/sec. Elapsed time 18.58 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 25.62 sec. Users per second: 532
# SearchBayesianSkopt: New best config found. Config 5: {'topK': 203, 'shrink': 5, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3468558, PRECISION_RECALL_MIN_DEN: 0.3481919, RECALL: 0.0590843, MAP: 0.2108352, MAP_MIN_DEN: 0.2115036, MRR: 0.6165091, NDCG: 0.3662917, F1: 0.1009693, HIT_RATE: 0.9505277, ARHR_ALL_HITS: 1.1206433, NOVELTY: 0.0053111, AVERAGE_POPULARITY: 0.6602081, DIVERSITY_MEAN_INTER_LIST: 0.8107764, DIVERSITY_HERFINDAHL: 0.9810717, COVERAGE_ITEM: 0.0547096, COVERAGE_ITEM_CORRECT: 0.0286284, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9501099, DIVERSITY_GINI: 0.0039838, SHANNON_ENTROPY: 6.3914257, RATIO_DIVERSITY_HERFINDAHL: 0.9814503, RATIO_DIVERSITY_GINI: 0.0160619, RATIO_SHANNON_ENTROPY: 0.5158292, RATIO_AVERAGE_POPULARITY: 3.2501478, RATIO_NOVELTY: 0.0249905,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 46.2779
# Function value obtained: -0.2108
# Current minimum: -0.2108
# Iteration No: 7 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 250, 'shrink': 5, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 935.49 column/sec. Elapsed time 19.30 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 28.53 sec. Users per second: 478
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 250, 'shrink': 5, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3464600, PRECISION_RECALL_MIN_DEN: 0.3477599, RECALL: 0.0590077, MAP: 0.2094049, MAP_MIN_DEN: 0.2099996, MRR: 0.6138276, NDCG: 0.3649648, F1: 0.1008406, HIT_RATE: 0.9521401, ARHR_ALL_HITS: 1.1145632, NOVELTY: 0.0053012, AVERAGE_POPULARITY: 0.6670911, DIVERSITY_MEAN_INTER_LIST: 0.7960978, DIVERSITY_HERFINDAHL: 0.9796039, COVERAGE_ITEM: 0.0517194, COVERAGE_ITEM_CORRECT: 0.0279639, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9517216, DIVERSITY_GINI: 0.0037079, SHANNON_ENTROPY: 6.2847235, RATIO_DIVERSITY_HERFINDAHL: 0.9799820, RATIO_DIVERSITY_GINI: 0.0149494, RATIO_SHANNON_ENTROPY: 0.5072176, RATIO_AVERAGE_POPULARITY: 3.2840321, RATIO_NOVELTY: 0.0249440,
#
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 50.2720
# Function value obtained: -0.2094
# Current minimum: -0.2108
# Iteration No: 8 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 227, 'shrink': 1, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 922.08 column/sec. Elapsed time 19.59 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 27.77 sec. Users per second: 491
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 227, 'shrink': 1, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3464893, PRECISION_RECALL_MIN_DEN: 0.3477952, RECALL: 0.0592325, MAP: 0.2100945, MAP_MIN_DEN: 0.2107102, MRR: 0.6134824, NDCG: 0.3653925, F1: 0.1011700, HIT_RATE: 0.9503811, ARHR_ALL_HITS: 1.1166225, NOVELTY: 0.0053074, AVERAGE_POPULARITY: 0.6636083, DIVERSITY_MEAN_INTER_LIST: 0.8031679, DIVERSITY_HERFINDAHL: 0.9803109, COVERAGE_ITEM: 0.0543219, COVERAGE_ITEM_CORRECT: 0.0286838, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9499634, DIVERSITY_GINI: 0.0038726, SHANNON_ENTROPY: 6.3406741, RATIO_DIVERSITY_HERFINDAHL: 0.9806892, RATIO_DIVERSITY_GINI: 0.0156134, RATIO_SHANNON_ENTROPY: 0.5117332, RATIO_AVERAGE_POPULARITY: 3.2668866, RATIO_NOVELTY: 0.0249733,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 49.9747
# Function value obtained: -0.2101
# Current minimum: -0.2108
# Iteration No: 9 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 209, 'shrink': 3, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 831.48 column/sec. Elapsed time 21.72 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 28.20 sec. Users per second: 484
# SearchBayesianSkopt: New best config found. Config 8: {'topK': 209, 'shrink': 3, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3470536, PRECISION_RECALL_MIN_DEN: 0.3483441, RECALL: 0.0592018, MAP: 0.2109276, MAP_MIN_DEN: 0.2116003, MRR: 0.6171596, NDCG: 0.3665138, F1: 0.1011492, HIT_RATE: 0.9508209, ARHR_ALL_HITS: 1.1214417, NOVELTY: 0.0053101, AVERAGE_POPULARITY: 0.6613100, DIVERSITY_MEAN_INTER_LIST: 0.8080642, DIVERSITY_HERFINDAHL: 0.9808005, COVERAGE_ITEM: 0.0547649, COVERAGE_ITEM_CORRECT: 0.0287945, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9504029, DIVERSITY_GINI: 0.0039539, SHANNON_ENTROPY: 6.3741662, RATIO_DIVERSITY_HERFINDAHL: 0.9811790, RATIO_DIVERSITY_GINI: 0.0159411, RATIO_SHANNON_ENTROPY: 0.5144362, RATIO_AVERAGE_POPULARITY: 3.2555721, RATIO_NOVELTY: 0.0249860,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 52.0727
# Function value obtained: -0.2109
# Current minimum: -0.2109
# Iteration No: 10 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'topK': 225, 'shrink': 5, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 996.76 column/sec. Elapsed time 18.12 sec
# EvaluatorHoldout: Processed 13644 (100.0%) in 27.89 sec. Users per second: 489
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 225, 'shrink': 5, 'similarity': 'cosine', 'normalize': True} - results: PRECISION: 0.3466505, PRECISION_RECALL_MIN_DEN: 0.3479659, RECALL: 0.0592212, MAP: 0.2103605, MAP_MIN_DEN: 0.2109916, MRR: 0.6139364, NDCG: 0.3656607, F1: 0.1011604, HIT_RATE: 0.9498681, ARHR_ALL_HITS: 1.1176593, NOVELTY: 0.0053057, AVERAGE_POPULARITY: 0.6640046, DIVERSITY_MEAN_INTER_LIST: 0.8030625, DIVERSITY_HERFINDAHL: 0.9803004, COVERAGE_ITEM: 0.0528822, COVERAGE_ITEM_CORRECT: 0.0281854, COVERAGE_USER: 0.9995604, COVERAGE_USER_CORRECT: 0.9494505, DIVERSITY_GINI: 0.0038442, SHANNON_ENTROPY: 6.3366212, RATIO_DIVERSITY_HERFINDAHL: 0.9806787, RATIO_DIVERSITY_GINI: 0.0154989, RATIO_SHANNON_ENTROPY: 0.5114061, RATIO_AVERAGE_POPULARITY: 3.2688374, RATIO_NOVELTY: 0.0249650,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 48.0994
# Function value obtained: -0.2104
# Current minimum: -0.2109
# SearchBayesianSkopt: Search complete. Best config is 8: {'topK': 209, 'shrink': 3, 'similarity': 'cosine', 'normalize': True}
#
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'topK': 209, 'shrink': 3, 'similarity': 'cosine', 'normalize': True}
# Similarity column 18059 (100.0%), 758.77 column/sec. Elapsed time 23.80 sec
# SearchBayesianSkopt: Saving model in result_experiments/ItemKNNCFRecommender
#
# ItemKNNCFRecommender: Saving model in file 'result_experiments/ItemKNNCFRecommender_best_model_last'
# ItemKNNCFRecommender: Saving complete

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")
search_metadata.keys()
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#   topK shrink similarity normalize
# 0  241      1     cosine      True
# 1  236      4     cosine      True
# 2  205      3     cosine      True
# 3  245      1     cosine      True
# 4  217      3     cosine      True
# 5  203      5     cosine      True
# 6  250      5     cosine      True
# 7  227      1     cosine      True
# 8  209      3     cosine      True
# 9  225      5     cosine      True

# %%
result_on_validation_df = search_metadata["result_on_validation_df"]
result_on_validation_df
# Out:
#          PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#   cutoff
# 0 10      0.346357                 0.347648  0.059047  0.209438    0.210038
# 1 10      0.346489                 0.347804  0.059065  0.209629    0.210245
# 2 10      0.347222                 0.348535  0.059229  0.210669    0.211334
# 3 10      0.346826                 0.348104  0.059064   0.20962    0.210208
# 4 10      0.346782                 0.348124  0.059271  0.210579    0.211243
# 5 10      0.346856                 0.348192  0.059084  0.210835    0.211504
# 6 10       0.34646                  0.34776  0.059008  0.209405        0.21
# 7 10      0.346489                 0.347795  0.059233  0.210095     0.21071
# 8 10      0.347054                 0.348344  0.059202  0.210928      0.2116
# 9 10      0.346651                 0.347966  0.059221  0.210361    0.210992
#
#                MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#   cutoff                                                        ...
# 0 10      0.609808  0.364499  0.100893  0.950015      1.111706  ...
# 1 10      0.611043   0.36492  0.100925  0.949721      1.113767  ...
# 2 10      0.616691   0.36636  0.101196  0.950894      1.120161  ...
# 3 10      0.611707  0.364939  0.100939  0.950308      1.113314  ...
# 4 10      0.616372  0.366166  0.101239  0.951481      1.120159  ...
# 5 10      0.616509  0.366292  0.100969  0.950528      1.120643  ...
# 6 10      0.613828  0.364965  0.100841   0.95214      1.114563  ...
# 7 10      0.613482  0.365392   0.10117  0.950381      1.116622  ...
# 8 10       0.61716  0.366514  0.101149  0.950821      1.121442  ...
# 9 10      0.613936  0.365661   0.10116  0.949868      1.117659  ...
#
#          COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
#   cutoff
# 0 10                  0.028573       0.99956              0.949597
# 1 10                  0.028628       0.99956              0.949304
# 2 10                  0.028905       0.99956              0.950476
# 3 10                  0.028407       0.99956               0.94989
# 4 10                  0.028684       0.99956              0.951062
# 5 10                  0.028628       0.99956               0.95011
# 6 10                  0.027964       0.99956              0.951722
# 7 10                  0.028684       0.99956              0.949963
# 8 10                  0.028795       0.99956              0.950403
# 9 10                  0.028185       0.99956              0.949451
#
#          DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
#   cutoff
# 0 10           0.003792        6.310843                   0.980275
# 1 10           0.003801        6.315361                   0.980343
# 2 10           0.003982        6.386984                   0.981351
# 3 10           0.003786        6.307683                   0.980212
# 4 10           0.003908        6.355163                   0.980916
# 5 10           0.003984        6.391426                    0.98145
# 6 10           0.003708        6.284724                   0.979982
# 7 10           0.003873        6.340674                   0.980689
# 8 10           0.003954        6.374166                   0.981179
# 9 10           0.003844        6.336621                   0.980679
#
#          RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
#   cutoff
# 0 10                 0.015287              0.509326                 3.276105
# 1 10                 0.015324               0.50969                 3.275339
# 2 10                 0.016054              0.515471                 3.251382
# 3 10                 0.015265              0.509071                 3.277581
# 4 10                 0.015755              0.512903                  3.26235
# 5 10                 0.016062              0.515829                 3.250148
# 6 10                 0.014949              0.507218                 3.284032
# 7 10                 0.015613              0.511733                 3.266887
# 8 10                 0.015941              0.514436                 3.255572
# 9 10                 0.015499              0.511406                 3.268837
#
#          RATIO_NOVELTY
#   cutoff
# 0 10          0.024961
# 1 10          0.024958
# 2 10          0.024991
# 3 10          0.024959
# 4 10          0.024977
# 5 10           0.02499
# 6 10          0.024944
# 7 10          0.024973
# 8 10          0.024986
# 9 10          0.024965
#
# [10 rows x 25 columns]

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'topK': 209, 'shrink': 3, 'similarity': 'cosine', 'normalize': True}
